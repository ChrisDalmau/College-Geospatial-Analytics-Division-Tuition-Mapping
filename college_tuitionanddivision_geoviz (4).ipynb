# %%
# !pip install geopy tqdm geopandas
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim
from tqdm import tqdm
import time
#import google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Overview
# - The csv below has over 1180 schools that have athletics programs in the US
# - The features ae the name, school_website, division, conference, tuition in state and out of state, gpa, and enrollment size.
# - The goal for this analysis is to determine whether the location of a college can affect the other features shownin the csv.
#
# #DISCLAIMER
# - This only analyzes schools that are in the NCAA and some from the NAIA

# %% [markdown]
# #Data Understanding
# - name: Names of colleges
# - school_website: The college's athletic website
# - division: The athletic division each college is in
# - conference: The athletic conference each college is in
# - tuition in state and out of state: cost to attend the college
# - gpa: the avg gpa in order to get accetped to th college
# - enrollment: Amount of people attending the school yearly

# %%
df = pd.read_csv('complete_college_data.csv')
df.head()
# Out:
#      id                           name                school_website division  \
# 0  1011      central christian college         https://ccctigers.com     NAIA
# 1  1133       arizona state university      https://thesundevils.com        I
# 2  1032  harris-stowe state university  https://hornetsathletics.com     NAIA
# 3  1080           the college of idaho     https://yoteathletics.com     NAIA
# 4   385            mount olive college        https://umotrojans.com       II
#
#           location                     conference  \
# 0    mcpherson, ks     sooner athletic conference
# 1        tempe, az                         big 12
# 2    st. louis, mo    american midwest conference
# 3     caldwell, id  cascade collegiate conference
# 4  mount olive, nc                      carolinas
#
#                                  source_url tuition_in_state  \
# 0                                       NaN            20650
# 1   https://www.ncaa.com/schools/arizona-st            12223
# 2                                       NaN             6058
# 3                                       NaN            34630
# 4  https://www.ncaa.com/schools/mount-olive            23591
#
#    tuition_out_of_state   gpa  enrollment  \
# 0                 20650  3.24       259.0
# 1                 33139  3.54     64778.0
# 2                 10690  3.04      1163.0
# 3                 34630  3.66      1055.0
# 4                 23591  2.85      2000.0
#
#                                            logo_link        logos
# 0                                                NaN  binary data
# 1                                                NaN  binary data
# 2                                                NaN  binary data
# 3                                                NaN          NaN
# 4  https://www.ncaa.com/sites/default/files/image...  binary data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1187 non-null   int64
#  1   name                  1187 non-null   object
#  2   school_website        1187 non-null   object
#  3   division              1187 non-null   object
#  4   location              1186 non-null   object
#  5   conference            1176 non-null   object
#  6   source_url            1049 non-null   object
#  7   tuition_in_state      1187 non-null   object
#  8   tuition_out_of_state  1187 non-null   int64
#  9   gpa                   1187 non-null   float64
#  10  enrollment            1184 non-null   float64
#  11  logo_link             999 non-null    object
#  12  logos                 1148 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 120.7+ KB

# %% [markdown]
# #We are using nomnation geocoder to convert each schools city and state into precise longitude and latitude coordiinates

# %%
# Initialize geocoder
geolocator = Nominatim(user_agent="college_mapper")

# %%
# Function to get latitude and longitude
def geocode_location(location):
    try:
        time.sleep(1)  # avoid overloading the API
        loc = geolocator.geocode(location + ", USA")
        if loc:
            return pd.Series([loc.latitude, loc.longitude])
    except:
        return pd.Series([None, None])
    return pd.Series([None, None])

# %%
# Create lat/lng columns
tqdm.pandas()
df[['latitude', 'longitude']] = df['location'].progress_apply(geocode_location)
# Out:
#   6%|▋         | 76/1187 [01:32<23:22,  1.26s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=tigerville%2C+sc%2C+USA&format=json&limit=1
#   7%|▋         | 83/1187 [01:42<22:43,  1.24s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=rapid+city%2C+sd%2C+USA&format=json&limit=1
#  11%|█         | 127/1187 [02:38<22:12,  1.26s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=new+orleans%2C+la%2C+USA&format=json&limit=1
#  14%|█▍        | 171/1187 [03:35<20:38,  1.22s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=evansville%2C+in%2C+USA&format=json&limit=1
#  19%|█▊        | 222/1187 [04:38<20:27,  1.27s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=mississippi+state%2C+ms%2C+USA&format=json&limit=1
#  23%|██▎       | 268/1187 [05:37<19:18,  1.26s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=winston%2C+nc%2C+USA&format=json&limit=1
#  27%|██▋       | 319/1187 [06:43<18:07,  1.25s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=louisville%2C+ky%2C+USA&format=json&limit=1
#  30%|██▉       | 351/1187 [07:24<16:47,  1.20s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=amherst%2C+ma%2C+USA&format=json&limit=1
#  30%|███       | 361/1187 [07:38<17:33,  1.28s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=lakewood%2C+co%2C+USA&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=lakewood%2C+co%2C+USA&format=json&limit=1
#  47%|████▋     | 557/1187 [11:48<12:40,  1.21s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=elizabethtown%2C+pa%2C+USA&format=json&limit=1
#  51%|█████     | 605/1187 [12:49<12:08,  1.25s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=st.+augustine%2C+fl%2C+USA&format=json&limit=1
#  58%|█████▊    | 689/1187 [14:34<10:08,  1.22s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=bronx%2C+ny%2C+USA&format=json&limit=1
#  62%|██████▏   | 731/1187 [15:27<08:59,  1.18s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=utica%2C+ny%2C+USA&format=json&limit=1
#  64%|██████▍   | 760/1187 [16:05<09:18,  1.31s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=st.+mary%27s+city%2C+md%2C+USA&format=json&limit=1
#  68%|██████▊   | 807/1187 [17:06<07:58,  1.26s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=chester%2C+pa%2C+USA&format=json&limit=1
#  70%|███████   | 834/1187 [17:40<07:13,  1.23s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=wooster%2C+oh%2C+USA&format=json&limit=1
#  82%|████████▏ | 972/1187 [20:35<04:23,  1.22s/it]WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=morehead%2C+ky%2C+USA&format=json&limit=1
# 100%|██████████| 1187/1187 [25:08<00:00,  1.27s/it]

# %%
df = df.dropna(subset=['latitude', 'longitude'])

# %% [markdown]
# - Below shows all colleges that are in the US that are seperated by division.
# - Clear indication that there are much more division 3 schools in the north compared to the south
# - Insights:
#   - Larger amount of schools north which is why there are more division 3 schools.
#   - Southern states focus more on athletics than academics which is why there are more division 1 schools.
#   - Because SEC is more competitive and Southern schools focus more on athletics they have more funding for scholarships, NIL money etc

# %%
import plotly.express as px

# Drop rows with missing coordinates or division
plot_df = df.dropna(subset=['latitude', 'longitude', 'division'])

fig = px.scatter_mapbox(
    plot_df,
    lat="latitude",
    lon="longitude",
    color="division",              # Use division as color category
    hover_name="name",
    hover_data={
        "division": True,
        "location": True,
        "gpa": True,
        "enrollment": True,
        "tuition_out_of_state": True,
        "latitude": False,
        "longitude": False
    },
    zoom=3,
    height=800,
    title="Interactive Map: Colleges by Division Across the U.S.",
)

fig.update_layout(mapbox_style="carto-positron")  # Same tile style as contextily
fig.update_layout(margin={"r":0,"t":40,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b
375448],["NAIA","winona lake, in",3.59,1337.0,29048,41.2272668,-85.8219345],["NAIA","des moines, ia",3.39,2064.0,32068,41.5868654,-93.6249494],["NAIA","lawrence, ks",3.03,784.0,480,38.9719137,-95.2359403],["NAIA","saint louis, mo",3.4,1109.0,33316,38.6280278,-90.1910154],["NAIA","butte, mt",3.56,2500.0,23210,46.0131505,-112.536508],["NAIA","montreat, nc",3.07,743.0,30525,35.6442841,-82.3028972],["NAIA","yankton, sd",3.55,1236.0,31500,42.8712938,-97.3967011],["NAIA","waxahachie, tx",3.16,1984.0,18610,32.3944908,-96.8439365],["NAIA","espanola, nm",2.0,785.0,14329,36.0028011,-106.0578009],["NAIA","kirkland, wa",3.48,1281.0,36298,47.6765382,-122.2070775],["NAIA","orange city, ia",3.6,1106.0,18475,43.0072424,-96.0583138],["NAIA","riverside, ca",3.6,1300.0,34902,33.9824949,-117.374238],["NAIA","oklahoma city, ok",3.83,2550.0,9564,35.4729886,-97.5170536],["NAIA","goodwell, ok",3.09,720.0,8385,36.5931666,-101.632544],["NAIA","bartlesville, ok",3.38,800.0,30262,36.7421089,-95.9528877],["NAIA","ottawa, ks",3.14,453.0,33380,39.1273653,-97.6568094],["NAIA","surprise, az",3.12,800.0,35300,33.629247,-112.3681428],["NAIA","peru, ne",3.31,1437.0,7920,40.481446,-95.730792],["NAIA","billings, mt",3.5,1031.0,22607,45.7874957,-108.49607],["NAIA","winfield, ks",3.4,635.0,9490,37.2397486,-96.9955919],["NAIA","talladega, al",2.4,1200.0,13866,33.3967079,-86.1597137],["NAIA","dallas, tx",3.25,4100.0,21758,32.776 ...

# %% [markdown]
# #Vizualization of tuition differences in the US by colleges with athletics programs
# #Insights:
#   - Much higher tuition cost for colleges in the north east, california is an expeception because the avg tuition there is very high.
#   - The southern states have slightly lower tuition cost.
#   - This may also be because there is a higher frequency of colleges in the north  than there is in the south.
#   - California schools and schools in the north primarily focus on quality education which is why the cost of attending is extremely high (not everyone can play sports and get a scholarship).
#   - Because the education quality is better getting a degree from the majority of universities in the north have more weight in the future when looking for a job than another school in the south.

# %%
import plotly.express as px

# Clean data (remove missing lat/lon or tuition)
plot_df = df.dropna(subset=["latitude", "longitude", "tuition_out_of_state"])

fig = px.scatter_geo(
    plot_df,
    lat="latitude",
    lon="longitude",
    color="tuition_out_of_state",
    hover_name="name",
    hover_data={
        "division": True,
        "location": True,
        "tuition_out_of_state": True,
        "gpa": True,
        "enrollment": True,
        "latitude": False,
        "longitude": False
    },
    color_continuous_scale="Viridis",
    scope="usa",
    title="Interactive Map: U.S. Colleges Colored by Out-of-State Tuition",
    height=800
)

fig.update_layout(
    margin={"r": 0, "t": 50, "l": 0, "b": 0},
    geo=dict(
        showland=True,
        landcolor="lightgray",
        lakecolor="white",
        showlakes=True,
        projection_type="albers usa"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id
6,7463.0,35.8272257,-90.6949871],["I","conway, ar",16728,3.6,7563.0,35.0891932,-92.4398402],["I","omaha, ne",21718,3.5,11866.0,41.2587459,-95.9383758],["III","cambridge, ma",31364,3.31,1406.0,42.3786343,-71.131738],["III","pittsburgh, pa",42125,3.7,1207.0,40.4416941,-79.9900861],["III","chicago, il",28654,4.32,21567.0,41.8755616,-87.6244212],["III","geneva, ny",61725,3.86,1539.0,42.8690271,-76.9786122],["II","chadron, ne",7834,3.15,1690.0,42.8309807,-103.0003729],["II","honolulu, hi",28544,3.5,1505.0,21.304547,-157.855676],["II","charleston, wv",29990,3.35,2330.0,38.3505995,-81.6332812],["II","philadelphia, pa",39410,3.12,939.0,39.9527237,-75.1635262],["II","bowie, md",19470,3.2,5289.0,38.9424464,-76.7301718],["II","bemidji, mn",10130,3.26,3187.0,47.4785418,-94.8907869],["II","waltham, ma",56500,3.79,4070.0,42.3756401,-71.2358004],["I","charleston, sc",29990,3.24,2771.0,32.7884363,-79.9399309],["I","charlotte, nc",21338,3.55,23063.0,35.2272086,-80.8430827],["I","chattanooga, tn",25966,3.6,9820.0,35.0457219,-85.3094883],["III","roanoke, va",41210,3.7,689.0,37.270973,-79.9 ...

# %%
#counting the amount of colleges in each state
state_counts = df['location'].str.split(', ').str[-1].value_counts()
state_counts = state_counts.reset_index()
state_counts.columns = ['state', 'count']
state_counts

#histogram with this dataframe using matplotlib
plt.figure(figsize=(30, 6))
plt.bar(state_counts['state'], state_counts['count'])
plt.xlabel('State')
plt.ylabel('Count')
plt.title('Count of Colleges by State')
# Out:
# Text(0.5, 1.0, 'Count of Colleges by State')

# %% [markdown]
# #Conclusion
# - Higher tuition rates and location do have a correlation with each other
# - There are multiple factors that come into play:
#   - amount of colleges in north east states, according to the histogram above northern states overall have more schools compared to southern states.
#   - tax differences in each state
#   - more private institutions up north which usually have higher tuition rates.
#   - Because of the difference in funding in education schools in the north will cost more to attend (not everyone can get a scholarship for sports or academics because of how competitive it is)
#
# - There are more Division III (D3) schools in the northern U.S.
# - Here's why:
#   - Higher Concentration of Private Colleges – Many D3 schools are private institutions, and the Northeast and Midwest have a long history of private liberal arts colleges that prioritize academics over athletics. People pay for luxuries included in D3 schools such as small class sizes, quality relations with professors, and more flexibility when it comes to choosing and changing a major, as well as the ability to even play a sport at the collegiate level
#
#   - Population Density & College Tradition – The northern states have a higher concentration of colleges overall, especially in states like Massachusetts, Pennsylvania, and New York, which have strong traditions of small, academically focused schools.
#   - Athletic Philosophy – D3 schools emphasize a balance between academics and athletics, and many northern institutions align with this philosophy rather than offering athletic scholarships like D1 and D2 schools.

# %% [markdown]
# Other things to explore to connect the dots:
#
# - Tuition vs. geography (region/state)
#
# - Enrollment vs. division level
#
# - GPA vs. tuition
# - GPA vs. location
#
# - Conference/division clustering patterns
